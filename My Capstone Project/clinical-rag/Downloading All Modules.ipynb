# %%
import os
print(os.getcwd())
#!pip install -r "/home/labuser/Desktop/Project/Capstone Project/requirements.txt"
# Out:
# /home/labuser/Downloads/clinical-rag

# %%
# !ls /home/labuser/Downloads/clinical-rag/requirements.txt
# Out:
# /home/labuser/Downloads/clinical-rag/requirements.txt

# %%
# !pip install -r "/home/labuser/Downloads/clinical-rag/requirements.txt"
# Out:
# ...
#   Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
# ...
#   Using cached langchain-1.2.3-py3-none-any.whl (106 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# ...
#   Using cached sentence_transformers-5.2.0-py3-none-any.whl (493 kB)
# ...
#   Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# ...
#   Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# ...
#   Using cached streamlit-1.52.2-py3-none-any.whl (9.0 MB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# ...
#   Using cached langchain_core-1.2.7-py3-none-any.whl (490 kB)
# ...
#   Using cached langgraph-1.0.5-py3-none-any.whl (157 kB)
# ...
#   Using cached aiohttp-3.13.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# ...
