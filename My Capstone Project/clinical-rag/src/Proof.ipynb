# %%
import os
print(os.getcwd())
# Out:
# /home/labuser/clinical-rag/src

# %% [raw]
# root@ip-172-31-45-203:/home/labuser/clinical-rag/src# python config.py
# root@ip-172-31-45-203:/home/labuser/clinical-rag/src# cd ..
# root@ip-172-31-45-203:/home/labuser/clinical-rag# pip install -r requirements.txt
# root@ip-172-31-45-203:/home/labuser/clinical-rag# python -m src.ingest
# Loading documents...
# Chunking documents...
# Saving chunks...
# Done. Created 2 chunks.
# root@ip-172-31-45-203:/home/labuser/clinical-rag# python -m src.embed_index
# Loading chunks...
# Loading embedding model...
# Embedding chunks...
# Batches: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 18.08it/s]
# Saving FAISS index...
# Saving metadata...
# Index built successfully!
# root@ip-172-31-45-203:/home/labuser/clinical-rag#
# root@ip-172-31-45-203:/home/labuser/clinical-rag# python -m src.safety
# root@ip-172-31-45-203:/home/labuser/clinical-rag#
# root@ip-172-31-45-203:/home/labuser/clinical-rag# python -m src.rag_pipeline
# root@ip-172-31-45-203:/home/labuser/clinical-rag#
# root@ip-172-31-45-203:/home/labuser# pgrep -af streamlit
# 34306 /usr/bin/python3 /usr/local/bin/streamlit run src/ui_streamlit.py
# 34604 /usr/bin/python3 /usr/local/bin/streamlit run src/ui_streamlit.py
# 34789 /usr/bin/python3 /usr/local/bin/streamlit run src/ui_streamlit.py
# 35365 /usr/bin/python3 /usr/local/bin/streamlit run src/ui_streamlit.py
# root@ip-172-31-45-203:/home/labuser# kill -9 34306 34604 34789 35365
# root@ip-172-31-45-203:/home/labuser# pgrep -af streamlit
# root@ip-172-31-45-203:/home/labuser# streamlit run src/ui_streamlit.py
